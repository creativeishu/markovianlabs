# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import cv2

from visual_search import VisualSearch as VS
# Out:
# Using Theano backend.

# %%
# dirname = '/Users/mohammed/Desktop/visualsearchtest/'
dirname = '/Users/mohammed/Dropbox/irshad2janu/deeplearning_datasets/image_classifiers/catsdogs/validation/cats/'
obj = VS(dirname)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
imgname = '/Users/mohammed/Downloads/06-train-cat-shake-hands.jpg'
x = obj.get_closest_filenames(imgname, plot=True)

# %%
imgname = '/Users/mohammed/Downloads/4-ways-cheer-up-depressed-cat.jpg'
x = obj.get_closest_filenames(imgname, plot=True)

# %%
imgname = '/Users/mohammed/Downloads/01-cat-wants-to-tell-you-laptop.jpg'
x = obj.get_closest_filenames(imgname, plot=True)

# %%
imgname = '/Users/mohammed/Downloads/tiger8.jpg'
x = obj.get_closest_filenames(imgname, plot=True)

# %%
imgname = '/Users/mohammed/Downloads/scroll000.jpg'
x = obj.get_closest_filenames(imgname, plot=True)

# %%
imgname = '/Users/mohammed/Downloads/too-cute-doggone-it-video-playlist.jpg'
x = obj.get_closest_filenames(imgname, plot=True)
