# %%
# %matplotlib inline
import numpy as np 
import matplotlib.pyplot as plt 
from imagepostprocessing import image_analysis
import cv2
# Out:
# Using Theano backend.

# %%
obj = image_analysis('vgg19')
labels = '/Users/mohammed/Dropbox/irshad2janu/deeplearning_datasets/image_classifiers/vggfiles/labels'

# %%
print dir(obj)
# Out:
# ['__class__', '__delattr__', '__dict__', '__doc__', '__format__', '__getattribute__', '__hash__', '__init__', '__module__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'get_features', 'get_features_vector', 'get_image_category', 'get_image_input', 'get_labels', 'get_layernames', 'inputshape', 'model', 'plot_all_conv_features', 'plot_conv_features']

# %%
print obj.get_layernames()
# Out:
# ['input_1', 'block1_conv1', 'block1_conv2', 'block1_pool', 'block2_conv1', 'block2_conv2', 'block2_pool', 'block3_conv1', 'block3_conv2', 'block3_conv3', 'block3_conv4', 'block3_pool', 'block4_conv1', 'block4_conv2', 'block4_conv3', 'block4_conv4', 'block4_pool', 'block5_conv1', 'block5_conv2', 'block5_conv3', 'block5_conv4', 'block5_pool', 'flatten', 'fc1', 'fc2', 'predictions']

# %%
print obj.model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
def analyse(image):
    plt.figure(figsize=(10,10))
    plt.imshow(cv2.imread(image))
    print obj.get_image_category(image,labels, k=5)
    obj.plot_conv_features(image)

# %%
image = '/Users/mohammed/Dropbox/deeplensing/Data/Simulation/SimLensPop/Data162/class_1_lens/img_class_1_lens_00003.png'
analyse(image)
# Out:
# {'jellyfish ': 0.048863433301448822, 'nematode, nematode worm, roundworm ': 0.11441751569509506, 'ski mask ': 0.051695413887500763, 'loudspeaker, speaker, speaker unit, loudspeaker system, speaker system ': 0.093651160597801208, 'velvet ': 0.10729359090328217}
# ...
# Layer name:  block1_conv1
# Features shape:  (1, 224, 224, 64)
# Number of rows and columns:  8 8
# ...

# %%
image = '/Users/mohammed/Desktop/me/me.JPG'
analyse(image)
# Out:
# {'kimono ': 0.019615607336163521, 'bow tie, bow-tie, bowtie ': 0.015417345799505711, 'torch ': 0.0087914448231458664, 'groom, bridegroom ': 0.85418665409088135, 'suit, suit of clothes ': 0.015407342463731766}
# ...
# Layer name:  block1_conv1
# Features shape:  (1, 224, 224, 64)
# Number of rows and columns:  8 8
# ...

# %%
image = '/Users/mohammed/Dropbox/irshad2janu/deeplearning_datasets/image_classifiers/test_images/vulture.jpeg'
analyse(image)
# Out:
# {'vulture ': 0.99900329113006592, 'white stork, Ciconia ciconia ': 4.9149097321787849e-05, 'black stork, Ciconia nigra ': 0.00021280566579662263, 'kite ': 0.00027216805028729141, 'hornbill ': 0.00035823136568069458}
# ...
# Layer name:  block1_conv1
# Features shape:  (1, 224, 224, 64)
# Number of rows and columns:  8 8
# ...
