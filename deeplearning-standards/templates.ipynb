# %% [markdown]
# # Sample codes for Regression and Classification problems

# %% [markdown]
# ## Important libraries to import

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas
import os
import h5py
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Sequential
from keras.layers import Convolution1D, Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.layers import Activation, Dropout, Flatten, Dense

# Forcing it to use theono as the backend
from keras import backend as K
K.set_image_dim_ordering('th')

np.random.seed(1234)
# Out:
# Using Theano backend.

# %% [markdown]
# ## To display the neural network

# %%
from IPython.display import SVG
from keras.utils.visualize_util import model_to_dot
def plot_model(thismodel):
    SVG(model_to_dot(thismodel).create(prog='dot', format='svg'))

# %% [markdown]
# # Regression problem:
#
# ## Loading datasets and splitting it into training and test set

# %%
filename = "/Users/mohammed/Dropbox/fermilabwork/with_myself/photoredshifts/data/FullTable_CMASS_irshad.csv"
dataframe = pandas.read_csv(filename)
dataset = dataframe.values

nn = int(len(dataset)*2/3)
X_train = dataset[:nn,1:13]
Y_train = dataset[:nn,14]
X_test = dataset[nn:,1:13]
Y_test = dataset[nn:,14]

print "Shape of X-train: ", X_train.shape
print "Shape of Y-train: ", Y_train.shape
print "Shape of X-test: ", X_test.shape
print "Shape of Y-test: ", Y_test.shape
# Out:
# Shape of X-train:  (435934, 12)
# Shape of Y-train:  (435934,)
# Shape of X-test:  (217967, 12)
# Shape of Y-test:  (217967,)

# %% [markdown]
# ## Sample of a fully connected architecture for regression

# %%
model = Sequential()
model.add(Dense(13, input_dim=X_train.shape[1], init='normal', activation='relu'))
model.add(Dense(128, activation='sigmoid'))
model.add(Dense(128, activation='sigmoid'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, init='normal'))
print model.summary()
model.compile(loss='mean_absolute_percentage_error', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, Y_train, batch_size=32, nb_epoch=2, verbose=1, validation_data=(X_test, Y_test))
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# dense_13 (Dense)                 (None, 13)            169         dense_input_4[0][0]
# ____________________________________________________________________________________________________
# dense_14 (Dense)                 (None, 128)           1792        dense_13[0][0]
# ____________________________________________________________________________________________________
# dense_15 (Dense)                 (None, 128)           16512       dense_14[0][0]
# ____________________________________________________________________________________________________
# dense_16 (Dense)                 (None, 128)           16512       dense_15[0][0]
# ____________________________________________________________________________________________________
# dense_17 (Dense)                 (None, 128)           16512       dense_16[0][0]
# ____________________________________________________________________________________________________
# dense_18 (Dense)                 (None, 1)             129         dense_17[0][0]
# ====================================================================================================
# Total params: 51,626
# Trainable params: 51,626
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# None
# Train on 435934 samples, validate on 217967 samples
# Epoch 1/2
# 435934/435934 [==============================] - 34s - loss: 7.9167 - acc: 0.0000e+00 - val_loss: 7.8408 - val_acc: 0.0000e+00
# Epoch 2/2
# 435934/435934 [==============================] - 46s - loss: 6.5902 - acc: 0.0000e+00 - val_loss: 6.5520 - val_acc: 0.0000e+00
